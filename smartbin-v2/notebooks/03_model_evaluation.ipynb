# %% [markdown]
# # SmartBin AI v2 — Interactive Model Evaluation & Error Diagnostics
# Interactive evaluation notebook computing PR curves, confusion matrices, and analyzing false positive/negative failure galleries.

# %%
from smartbin_v2.evaluation.evaluator import WasteModelEvaluator

evaluator = WasteModelEvaluator(weights_path='best.pt')
metrics = evaluator.evaluate(split='val')
print(f'Validation mAP@50: {metrics.map50 * 100:.2f}% | Latency: {metrics.total_latency_ms:.1f}ms')
