# %% [markdown]
# # SmartBin AI v2 — Dataset Exploration & Taxonomy Distribution
# Explores the 28 Indian waste classes, class frequency imbalances, and spatial bounding box distributions.

# %%
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

with open('../datasets/indian_waste_taxonomy.json') as f:
    tax = json.load(f)

df = pd.DataFrame(tax['classes'])
print('Total Target Classes:', len(df))
df[['id', 'name', 'category', 'target_bin']].head(10)
